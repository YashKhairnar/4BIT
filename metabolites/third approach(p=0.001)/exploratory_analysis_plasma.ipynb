# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plasma = pd.read_csv('D:\GitHub\\4BIT\metabolites\dataset\plasma_processed.csv')
plasma = plasma.drop(['Unnamed: 0'], axis=1)
plasma
# Out:
#     1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                  9483            103                              101
# 1                 27468            207                              155
# 2                 13976             86                               78
# 3                 19449            178                              104
# 4                 17209            258                              103
# ..                  ...            ...                              ...
# 77                25149            184                              154
# 78                24181            142                              135
# 79                23848            118                               65
# 80                13848             97                               65
# 81                19669            187                              177
#
#     2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                       963                389                   123
# 1                       335                227                   178
# 2                       176                152                    83
# 3                       467                270                   157
# 4                       979                314                   211
# ..                      ...                ...                   ...
# 77                      444                142                   244
# 78                      786                226                   146
# 79                      132                352                   294
# 80                      881                444                   122
# 81                      450                166                   171
#
#     2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# 0                    20744                     139                      36
# 1                     8611                      78                      91
# 2                    22792                      92                      97
# 3                    29418                     123                      92
# 4                    16713                      76                      42
# ..                     ...                     ...                     ...
# 77                   20728                      51                     128
# 78                   10688                      64                      59
# 79                   10077                      42                      56
# 80                   14869                      75                     203
# 81                   14464                      23                     258
#
#     2-hydroxyvaleric acid  ...  tryptophan  tyrosine  UDP-glucuronic acid  \
# 0                     955  ...       27450     52403                   73
# 1                     103  ...       17898     37179                  157
# 2                    1010  ...       29503     30670                  211
# 3                     289  ...       16501     27573                   71
# 4                    1126  ...       24023     30096                  222
# ..                    ...  ...         ...       ...                  ...
# 77                    186  ...       30518     36411                  114
# 78                     80  ...       23731     26506                  110
# 79                    867  ...       30277     35764                  158
# 80                   1104  ...       14930     18921                 2176
# 81                    984  ...       17881     28443                   57
#
#       urea  uric acid  uridine  valine  xylitol  xylose    Class
# 0   255067      10057       63  157332      154    1380  disease
# 1   180080       8386      118  103083      324     929  disease
# 2   138861      15822      119   92045      253     610  disease
# 3   183633      14024      102   97349      223     746  disease
# 4   255081      23154       58  159671      189    2022  disease
# ..     ...        ...      ...     ...      ...     ...      ...
# 77  226793      17880       57  114920      252     856  control
# 78  365044      29018       61  127248      359    1003  control
# 79  327943      19736       76   78152      453    1279  control
# 80  323303      17479      108   96830     1450    1045  control
# 81  190031      32421       79  122408      225    2585  control
#
# [82 rows x 159 columns]

# %%
plasma.dtypes
# Out:
# 1_5-anhydroglucitol                 int64
# 1-monostearin                       int64
# 2_3-dihydroxybutanoic acid NIST     int64
# 2_4-diaminobutyric acid             int64
# 2-deoxyerythritol                   int64
#                                     ...
# uridine                             int64
# valine                              int64
# xylitol                             int64
# xylose                              int64
# Class                              object
# Length: 159, dtype: object

# %% [markdown]
# # Deal with NaN Values:

# %%
plasma.isnull().any()
# Out:
# 1_5-anhydroglucitol                False
# 1-monostearin                      False
# 2_3-dihydroxybutanoic acid NIST    False
# 2_4-diaminobutyric acid            False
# 2-deoxyerythritol                  False
#                                    ...
# uridine                            False
# valine                             False
# xylitol                            False
# xylose                             False
# Class                              False
# Length: 159, dtype: bool

# %%
# plasma.corr()

# %%
from scipy import stats

pearson_p = []
for i in plasma.columns:
    if plasma[i].dtypes!='O':
        pearson_coef, p_value = stats.pearsonr(plasma[i], plasma['Class'].map({"control": 0, "disease": 1}))
        pearson_p.append([i, pearson_coef, p_value])
pearson_p_df = pd.DataFrame(pearson_p, columns=['Features', 'Pearson Coefficient', 'p-Value'])
pearson_p_df
# Out:
#                             Features  Pearson Coefficient   p-Value
# 0                1_5-anhydroglucitol            -0.051611  0.645167
# 1                      1-monostearin             0.176846  0.111975
# 2    2_3-dihydroxybutanoic acid NIST             0.076688  0.493476
# 3            2_4-diaminobutyric acid             0.076201  0.496233
# 4                  2-deoxyerythritol             0.060320  0.590351
# ..                               ...                  ...       ...
# 153                        uric acid            -0.310864  0.004475
# 154                          uridine            -0.001496  0.989356
# 155                           valine            -0.094143  0.400187
# 156                          xylitol            -0.068039  0.543606
# 157                           xylose             0.047451  0.672058
#
# [158 rows x 3 columns]

# %%
pearson_p_final = []
for i in range(158):
    if pearson_p_df.loc[i, 'p-Value'] < 0.001:
        pearson_p_final.append(pearson_p_df.loc[i, 'Features'])
pearson_p_final
# Out:
# ['3-phosphoglycerate',
#  '5-methoxytryptamine',
#  'adenosine-5-monophosphate',
#  'asparagine',
#  'aspartic acid',
#  'lactic acid',
#  'phenol',
#  'pyrophosphate',
#  'pyruvic acid',
#  'taurine']

# %% [markdown]
# ### So important variables we derived:
#
# '3-phosphoglycerate',
#  '5-methoxytryptamine',
#  'adenosine-5-monophosphate',
#  'asparagine',
#  'aspartic acid',
#  'lactic acid',
#  'phenol',
#  'pyrophosphate',
#  'pyruvic acid',
#  'taurine'

# %%
# necessary functions
from sklearn.decomposition import PCA
labels = np.reshape(plasma['Class'].to_numpy(), (82,1))

def pca_analysis(df, n_components):
    pca = PCA(n_components=n_components)
    pca_result = pca.fit_transform(df.iloc[:, :-1].values)

    pca_concatenate = np.concatenate([pca_result, labels], axis=1)
    return pca_concatenate

def make_dataframe(array, n_features):
    col = []
    for i in range(1, n_features+1):
        col.append(f'pc{i}')
    col.append('Class')
    return pd.DataFrame(array, columns = col)

from sklearn.manifold import TSNE
def tsne_analysis(df, n_components):
    tsne = TSNE(n_components=n_components)
    tsne_result = tsne.fit_transform(df.iloc[:, :-1].values)

    tsne_concatenate = np.concatenate([tsne_result, labels], axis=1)
    return tsne_concatenate
def tsne_dataframe(array, n_features):
    col = []
    for i in range(1, n_features+1):
        col.append(f'tsne{i}')
    col.append('Class')
    return pd.DataFrame(array, columns = col)

def get_xy(df):
  X = df.drop('Class', axis=1)
  X = X.apply(pd.to_numeric)
  y = df['Class'].copy()
  y = y.map({"control": 0, "disease": 1})
  return X, y

# %% [markdown]
# # Lzypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import classification_report

from sklearn.model_selection import ShuffleSplit, train_test_split, StratifiedKFold

# %%
imp0 = ['3-phosphoglycerate',
 '5-methoxytryptamine',
 'adenosine-5-monophosphate',
 'asparagine',
 'aspartic acid',
 'lactic acid',
 'phenol',
 'pyrophosphate',
 'pyruvic acid',
 'taurine']

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
accuracy = []
for k in [0, 2, 3, 4, 5, 22, 23]:
    
    if k==0:
        name = ['Plasma(Exploratory)']
        dfs = [plasma[imp0]]
    
    elif k==22 or k==23:
        k -= 20
        name = [f'tsne{k}_plasma(Exploratory)']
        vars()[f'tsne{k}_plasma'] = tsne_analysis(plasma[imp0], k)
        vars()[f'tsne{k}_plasma_df'] = make_dataframe(vars()[f'tsne{k}_plasma'], k)
        dfs = [vars()[f'tsne{k}_plasma_df']]
    
    else:
        name = [f'pca{k}_plasma(Exploratory)']
        vars()[f'pca{k}_plasma'] = pca_analysis(plasma[imp0], k)
        vars()[f'pca{k}_plasma_df'] = make_dataframe(vars()[f'pca{k}_plasma'], k)
        
        dfs = [vars()[f'pca{k}_plasma_df']]
    
    random_state = 42

    for idx, data in enumerate(dfs):
        result = []
        if data.columns[-1]=='Class':
            X = data.drop('Class', axis=1)
        else:
            X = data
        y = plasma['Class'].copy()
        y = y.map({"control": 0, "disease": 1})
        rs = ShuffleSplit(n_splits=10, test_size=.2, random_state=random_state)

        for train_index, test_index in rs.split(X):
            clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=matthews_corrcoef, predictions=True)
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            cols = X_train.columns
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.transform(X_test)

            X_train = pd.DataFrame(X_train, columns=[cols])
            X_test = pd.DataFrame(X_test, columns=[cols])

            models, predictions = clf.fit(X_train, X_test, y_train, y_test)
            result.append(models)
        #     print(result)

        acc = []
        for i in range(10):
            acc.append(result[i].iloc[0]['Balanced Accuracy'])

        print(f'\n{name[idx]}: {sum(acc)/len(acc)}')
        accuracy.append([f'{name[idx]}', f'{sum(acc)/len(acc)}'])
# Out:
#   3%|▎         | 1/29 [00:00<00:03,  7.88it/s]
# 100%|██████████| 29/29 [00:01<00:00, 17.19it/s]
# [LightGBM] [Info] Number of positive: 30, number of negative: 35
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000054 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 226
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.461538 -> initscore=-0.154151
# [LightGBM] [Info] Start training from score -0.154151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:01<00:00, 26.50it/s]
# [LightGBM] [Info] Number of positive: 33, number of negative: 32
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 233
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507692 -> initscore=0.030772
# [LightGBM] [Info] Start training from score 0.030772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:01<00:00, 19.78it/s]
# [LightGBM] [Info] Number of positive: 28, number of negative: 37
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000035 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 230
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.430769 -> initscore=-0.278713
# [LightGBM] [Info] Start training from score -0.278713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:01<00:00, 28.20it/s]
# [LightGBM] [Info] Number of positive: 33, number of negative: 32
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 234
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507692 -> initscore=0.030772
# [LightGBM] [Info] Start training from score 0.030772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:00<00:00, 33.52it/s]
# [LightGBM] [Info] Number of positive: 35, number of negative: 30
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 227
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.538462 -> initscore=0.154151
# [LightGBM] [Info] Start training from score 0.154151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:01<00:00, 17.99it/s]
# [LightGBM] [Info] Number of positive: 32, number of negative: 33
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000046 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 228
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.492308 -> initscore=-0.030772
# [LightGBM] [Info] Start training from score -0.030772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 70
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.538462 -> initscore=0.154151
# [LightGBM] [Info] Start training from score 0.154151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:00<00:00, 29.48it/s]
# [LightGBM] [Info] Number of positive: 33, number of negative: 32
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 71
# [LightGBM] [Info] Number of data points in the train set: 65, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507692 -> initscore=0.030772
# [LightGBM] [Info] Start training from score 0.030772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# tsne3_plasma(Exploratory): 0.7571474358974359

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelPropagation                   0.76               0.76     0.76      0.76
# LabelSpreading                     0.76               0.76     0.76      0.76
# LGBMClassifier                     0.71               0.72     0.72      0.70
# PassiveAggressiveClassifier        0.71               0.71     0.71      0.71
# KNeighborsClassifier               0.71               0.71     0.71      0.71
# BernoulliNB                        0.71               0.70     0.70      0.70
# NuSVC                              0.71               0.70     0.70      0.70
# QuadraticDiscriminantAnalysis      0.65               0.65     0.65      0.64
# SGDClassifier                      0.59               0.60     0.60      0.58
# LogisticRegression                 0.59               0.59     0.59      0.59
# SVC                                0.59               0.59     0.59      0.59
# RidgeClassifierCV                  0.59               0.59     0.59      0.59
# RidgeClassifier                    0.59               0.59     0.59      0.59
# NearestCentroid                    0.59               0.59     0.59      0.59
# LinearSVC                          0.59               0.59     0.59      0.59
# BaggingClassifier                  0.59               0.59     0.59      0.59
# LinearDiscriminantAnalysis         0.59               0.59     0.59      0.59
# GaussianNB                         0.59               0.59     0.59      0.59
# ExtraTreesClassifier               0.59               0.59     0.59      0.59
# CalibratedClassifierCV             0.59               0.59     0.59      0.59
# RandomForestClassifier             0.53               0.53     0.53      0.53
# ExtraTreeClassifier                0.53               0.53     0.53      0.53
# XGBClassifier                      0.53               0.53     0.53      0.53
# DummyClassifier                    0.47               0.50     0.50      0.30
# AdaBoostClassifier                 0.47               0.47     0.47      0.47
# DecisionTreeClassifier             0.47               0.47     0.47      0.47
# Perceptron                         0.41               0.43     0.43      0.34
#
#                                matthews_corrcoef  Time Taken
# Model
# LabelPropagation                            0.53        0.01
# LabelSpreading                              0.53        0.02
# LGBMClassifier                              0.45        0.03
# PassiveAggressiveClassifier                 0.42        0.01
# KNeighborsClassifier                        0.42        0.03
# BernoulliNB                                 0.41        0.02
# NuSVC                                       0.41        0.02
# QuadraticDiscriminantAnalysis               0.31        0.02
# SGDClassifier                               0.20        0.02
# LogisticRegression                          0.18        0.02
# SVC                                         0.18        0.02
# RidgeClassifierCV                           0.18        0.02
# RidgeClassifier                             0.18        0.02
# NearestCentroid                             0.18        0.02
# LinearSVC                                   0.18        0.00
# BaggingClassifier                           0.18        0.04
# LinearDiscriminantAnalysis                  0.18        0.01
# GaussianNB                                  0.18        0.02
# ExtraTreesClassifier                        0.18        0.13
# CalibratedClassifierCV                      0.18        0.04
# RandomForestClassifier                      0.07        0.19
# ExtraTreeClassifier                         0.07        0.03
# XGBClassifier                               0.07        0.06
# DummyClassifier                             0.00        0.03
# AdaBoostClassifier                         -0.06        0.12
# DecisionTreeClassifier                     -0.07        0.02
# Perceptron                                 -0.18        0.00

# %%
result
# Out:
# [                               Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  XGBClassifier                      0.76               0.78     0.78      0.77
#  BernoulliNB                        0.71               0.70     0.70      0.71
#  LGBMClassifier                     0.65               0.65     0.65      0.65
#  RandomForestClassifier             0.65               0.65     0.65      0.65
#  ExtraTreesClassifier               0.65               0.65     0.65      0.65
#  GaussianNB                         0.65               0.65     0.65      0.65
#  ExtraTreeClassifier                0.59               0.64     0.64      0.59
#  NuSVC                              0.65               0.61     0.61      0.65
#  SVC                                0.65               0.61     0.61      0.65
#  RidgeClassifierCV                  0.59               0.61     0.61      0.60
#  KNeighborsClassifier               0.59               0.57     0.57      0.59
#  Perceptron                         0.59               0.57     0.57      0.59
#  DecisionTreeClassifier             0.53               0.56     0.56      0.54
#  PassiveAggressiveClassifier        0.47               0.55     0.55      0.44
#  NearestCentroid                    0.59               0.53     0.53      0.58
#  QuadraticDiscriminantAnalysis      0.53               0.52     0.52      0.54
#  LabelSpreading                     0.53               0.52     0.52      0.54
#  LogisticRegression                 0.53               0.52     0.52      0.54
#  CalibratedClassifierCV             0.53               0.52     0.52      0.54
#  DummyClassifier                    0.35               0.50     0.50      0.18
#  LabelPropagation                   0.47               0.48     0.48      0.48
#  SGDClassifier                      0.41               0.47     0.47      0.40
#  LinearSVC                          0.47               0.44     0.44      0.48
#  RidgeClassifier                    0.47               0.44     0.44      0.48
#  LinearDiscriminantAnalysis         0.47               0.44     0.44      0.48
#  BaggingClassifier                  0.35               0.39     0.39      0.35
#  AdaBoostClassifier                 0.41               0.36     0.36      0.41
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  XGBClassifier                               0.54        0.13
#  BernoulliNB                                 0.38        0.05
#  LGBMClassifier                              0.29        0.07
#  RandomForestClassifier                      0.29        0.35
#  ExtraTreesClassifier                        0.29        0.27
#  GaussianNB                                  0.29        0.03
#  ExtraTreeClassifier                         0.29        0.05
#  NuSVC                                       0.23        0.04
#  SVC                                         0.23        0.04
#  RidgeClassifierCV                           0.20        0.04
#  KNeighborsClassifier                        0.13        0.04
#  Perceptron                                  0.13        0.04
#  DecisionTreeClassifier                      0.12        0.03
#  PassiveAggressiveClassifier                 0.12        0.03
#  NearestCentroid                             0.06        0.05
#  QuadraticDiscriminantAnalysis               0.04        0.03
#  LabelSpreading                              0.04        0.05
#  LogisticRegression                          0.04        0.05
#  CalibratedClassifierCV                      0.04        0.09
#  DummyClassifier                             0.00        0.03
#  LabelPropagation                           -0.04        0.03
#  SGDClassifier                              -0.06        0.04
#  LinearSVC                                  -0.12        0.03
#  RidgeClassifier                            -0.12        0.05
#  LinearDiscriminantAnalysis                 -0.12        0.03
#  BaggingClassifier                          -0.23        0.08
#  AdaBoostClassifier                         -0.29        0.25  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  PassiveAggressiveClassifier        0.71               0.72     0.72      0.70
#  DecisionTreeClassifier             0.71               0.70     0.70      0.70
#  BaggingClassifier                  0.71               0.70     0.70      0.70
#  AdaBoostClassifier                 0.71               0.69     0.69      0.69
#  LinearDiscriminantAnalysis         0.65               0.65     0.65      0.65
#  SVC                                0.65               0.65     0.65      0.65
#  RidgeClassifierCV                  0.65               0.65     0.65      0.65
#  RidgeClassifier                    0.65               0.65     0.65      0.65
#  NearestCentroid                    0.65               0.65     0.65      0.65
#  LogisticRegression                 0.65               0.65     0.65      0.65
#  LinearSVC                          0.65               0.65     0.65      0.65
#  KNeighborsClassifier               0.65               0.65     0.65      0.65
#  GaussianNB                         0.65               0.65     0.65      0.65
#  ExtraTreesClassifier               0.65               0.65     0.65      0.65
#  BernoulliNB                        0.65               0.65     0.65      0.65
#  LabelSpreading                     0.65               0.64     0.64      0.64
#  LabelPropagation                   0.65               0.64     0.64      0.64
#  RandomForestClassifier             0.65               0.64     0.64      0.64
#  NuSVC                              0.59               0.59     0.59      0.59
#  LGBMClassifier                     0.59               0.59     0.59      0.59
#  QuadraticDiscriminantAnalysis      0.59               0.58     0.58      0.59
#  CalibratedClassifierCV             0.59               0.58     0.58      0.59
#  XGBClassifier                      0.59               0.58     0.58      0.59
#  ExtraTreeClassifier                0.53               0.53     0.53      0.53
#  DummyClassifier                    0.47               0.50     0.50      0.30
#  SGDClassifier                      0.47               0.50     0.50      0.30
#  Perceptron                         0.35               0.33     0.33      0.28
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  PassiveAggressiveClassifier                 0.45        0.03
#  DecisionTreeClassifier                      0.41        0.03
#  BaggingClassifier                           0.41        0.08
#  AdaBoostClassifier                          0.43        0.28
#  LinearDiscriminantAnalysis                  0.29        0.03
#  SVC                                         0.29        0.05
#  RidgeClassifierCV                           0.29        0.04
#  RidgeClassifier                             0.29        0.05
#  NearestCentroid                             0.29        0.05
#  LogisticRegression                          0.29        0.05
#  LinearSVC                                   0.29        0.05
#  KNeighborsClassifier                        0.29        0.04
#  GaussianNB                                  0.29        0.05
#  ExtraTreesClassifier                        0.29        0.29
#  BernoulliNB                                 0.29        0.03
#  LabelSpreading                              0.29        0.03
#  LabelPropagation                            0.29        0.03
#  RandomForestClassifier                      0.29        0.44
#  NuSVC                                       0.18        0.05
#  LGBMClassifier                              0.18        0.08
#  QuadraticDiscriminantAnalysis               0.17        0.05
#  CalibratedClassifierCV                      0.17        0.08
#  XGBClassifier                               0.17        0.12
#  ExtraTreeClassifier                         0.06        0.03
#  DummyClassifier                             0.00        0.03
#  SGDClassifier                               0.00        0.04
#  Perceptron                                 -0.44        0.03  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  DecisionTreeClassifier             0.53               0.69     0.69      0.54
#  KNeighborsClassifier               0.65               0.68     0.68      0.67
#  ExtraTreesClassifier               0.59               0.64     0.64      0.62
#  RandomForestClassifier             0.53               0.61     0.61      0.56
#  CalibratedClassifierCV             0.53               0.61     0.61      0.56
#  XGBClassifier                      0.53               0.61     0.61      0.56
#  SGDClassifier                      0.35               0.58     0.58      0.30
#  QuadraticDiscriminantAnalysis      0.47               0.57     0.57      0.50
#  BaggingClassifier                  0.47               0.57     0.57      0.50
#  LGBMClassifier                     0.47               0.57     0.57      0.50
#  NearestCentroid                    0.59               0.56     0.56      0.62
#  LabelPropagation                   0.41               0.53     0.53      0.43
#  LabelSpreading                     0.41               0.53     0.53      0.43
#  SVC                                0.53               0.52     0.52      0.57
#  NuSVC                              0.53               0.52     0.52      0.57
#  DummyClassifier                    0.24               0.50     0.50      0.09
#  RidgeClassifierCV                  0.47               0.48     0.48      0.51
#  RidgeClassifier                    0.47               0.48     0.48      0.51
#  LinearSVC                          0.47               0.48     0.48      0.51
#  LogisticRegression                 0.47               0.48     0.48      0.51
#  LinearDiscriminantAnalysis         0.47               0.48     0.48      0.51
#  GaussianNB                         0.47               0.48     0.48      0.51
#  ExtraTreeClassifier                0.47               0.48     0.48      0.51
#  BernoulliNB                        0.47               0.48     0.48      0.51
#  Perceptron                         0.71               0.46     0.46      0.63
#  PassiveAggressiveClassifier        0.53               0.43     0.43      0.56
#  AdaBoostClassifier                 0.35               0.40     0.40      0.38
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  DecisionTreeClassifier                      0.36        0.05
#  KNeighborsClassifier                        0.31        0.05
#  ExtraTreesClassifier                        0.25        0.31
#  RandomForestClassifier                      0.18        0.39
#  CalibratedClassifierCV                      0.18        0.08
#  XGBClassifier                               0.18        0.16
#  SGDClassifier                               0.20        0.03
#  QuadraticDiscriminantAnalysis               0.12        0.03
#  BaggingClassifier                           0.12        0.10
#  LGBMClassifier                              0.12        0.09
#  NearestCentroid                             0.10        0.05
#  LabelPropagation                            0.05        0.05
#  LabelSpreading                              0.05        0.05
#  SVC                                         0.03        0.03
#  NuSVC                                       0.03        0.05
#  DummyClassifier                             0.00        0.03
#  RidgeClassifierCV                          -0.03        0.05
#  RidgeClassifier                            -0.03        0.03
#  LinearSVC                                  -0.03        0.04
#  LogisticRegression                         -0.03        0.05
#  LinearDiscriminantAnalysis                 -0.03        0.05
#  GaussianNB                                 -0.03        0.05
#  ExtraTreeClassifier                        -0.03        0.03
#  BernoulliNB                                -0.03        0.05
#  Perceptron                                 -0.14        0.05
#  PassiveAggressiveClassifier                -0.12        0.05
#  AdaBoostClassifier                         -0.17        0.41  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  SVC                                0.88               0.88     0.88      0.88
#  Perceptron                         0.82               0.81     0.81      0.82
#  XGBClassifier                      0.76               0.76     0.76      0.76
#  KNeighborsClassifier               0.76               0.76     0.76      0.76
#  NearestCentroid                    0.76               0.76     0.76      0.76
#  ExtraTreesClassifier               0.76               0.76     0.76      0.76
#  CalibratedClassifierCV             0.76               0.75     0.75      0.75
#  NuSVC                              0.71               0.72     0.72      0.70
#  BernoulliNB                        0.71               0.71     0.71      0.71
#  LinearSVC                          0.71               0.70     0.70      0.70
#  BaggingClassifier                  0.71               0.70     0.70      0.70
#  RidgeClassifierCV                  0.71               0.70     0.70      0.70
#  LogisticRegression                 0.71               0.70     0.70      0.70
#  LabelPropagation                   0.71               0.70     0.70      0.70
#  LinearDiscriminantAnalysis         0.71               0.70     0.70      0.70
#  LabelSpreading                     0.71               0.70     0.70      0.70
#  RidgeClassifier                    0.71               0.70     0.70      0.70
#  GaussianNB                         0.71               0.70     0.70      0.70
#  RandomForestClassifier             0.71               0.70     0.70      0.70
#  QuadraticDiscriminantAnalysis      0.65               0.64     0.64      0.64
#  DecisionTreeClassifier             0.65               0.63     0.63      0.62
#  LGBMClassifier                     0.59               0.58     0.58      0.59
#  AdaBoostClassifier                 0.53               0.53     0.53      0.53
#  ExtraTreeClassifier                0.53               0.53     0.53      0.53
#  PassiveAggressiveClassifier        0.47               0.50     0.50      0.30
#  SGDClassifier                      0.47               0.50     0.50      0.30
#  DummyClassifier                    0.47               0.50     0.50      0.30
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  SVC                                         0.76        0.02
#  Perceptron                                  0.68        0.01
#  XGBClassifier                               0.53        0.03
#  KNeighborsClassifier                        0.53        0.03
#  NearestCentroid                             0.53        0.00
#  ExtraTreesClassifier                        0.54        0.28
#  CalibratedClassifierCV                      0.59        0.09
#  NuSVC                                       0.45        0.02
#  BernoulliNB                                 0.42        0.03
#  LinearSVC                                   0.41        0.01
#  BaggingClassifier                           0.41        0.09
#  RidgeClassifierCV                           0.41        0.02
#  LogisticRegression                          0.41        0.02
#  LabelPropagation                            0.41        0.03
#  LinearDiscriminantAnalysis                  0.41        0.02
#  LabelSpreading                              0.41        0.02
#  RidgeClassifier                             0.41        0.02
#  GaussianNB                                  0.41        0.03
#  RandomForestClassifier                      0.41        0.14
#  QuadraticDiscriminantAnalysis               0.29        0.01
#  DecisionTreeClassifier                      0.31        0.05
#  LGBMClassifier                              0.17        0.04
#  AdaBoostClassifier                          0.07        0.27
#  ExtraTreeClassifier                         0.06        0.03
#  PassiveAggressiveClassifier                 0.00        0.03
#  SGDClassifier                               0.00        0.01
#  DummyClassifier                             0.00        0.03  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  XGBClassifier                      0.65               0.65     0.65      0.65
#  QuadraticDiscriminantAnalysis      0.65               0.61     0.61      0.65
#  LGBMClassifier                     0.59               0.61     0.61      0.60
#  LabelSpreading                     0.65               0.58     0.58      0.63
#  LabelPropagation                   0.65               0.58     0.58      0.63
#  SVC                                0.59               0.57     0.57      0.59
#  RidgeClassifierCV                  0.59               0.57     0.57      0.59
#  RidgeClassifier                    0.59               0.57     0.57      0.59
#  NuSVC                              0.59               0.57     0.57      0.59
#  NearestCentroid                    0.59               0.57     0.57      0.59
#  LinearDiscriminantAnalysis         0.59               0.57     0.57      0.59
#  LinearSVC                          0.59               0.57     0.57      0.59
#  GaussianNB                         0.59               0.57     0.57      0.59
#  DecisionTreeClassifier             0.59               0.57     0.57      0.59
#  CalibratedClassifierCV             0.59               0.57     0.57      0.59
#  BernoulliNB                        0.59               0.57     0.57      0.59
#  PassiveAggressiveClassifier        0.65               0.54     0.54      0.59
#  Perceptron                         0.59               0.53     0.53      0.58
#  ExtraTreeClassifier                0.59               0.53     0.53      0.58
#  LogisticRegression                 0.53               0.52     0.52      0.54
#  DummyClassifier                    0.35               0.50     0.50      0.18
#  KNeighborsClassifier               0.53               0.48     0.48      0.53
#  BaggingClassifier                  0.53               0.48     0.48      0.53
#  ExtraTreesClassifier               0.53               0.48     0.48      0.53
#  RandomForestClassifier             0.53               0.48     0.48      0.53
#  SGDClassifier                      0.47               0.44     0.44      0.48
#  AdaBoostClassifier                 0.47               0.44     0.44      0.48
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  XGBClassifier                               0.29        0.04
#  QuadraticDiscriminantAnalysis               0.23        0.02
#  LGBMClassifier                              0.20        0.03
#  LabelSpreading                              0.17        0.01
#  LabelPropagation                            0.17        0.04
#  SVC                                         0.13        0.04
#  RidgeClassifierCV                           0.13        0.02
#  RidgeClassifier                             0.13        0.02
#  NuSVC                                       0.13        0.01
#  NearestCentroid                             0.13        0.03
#  LinearDiscriminantAnalysis                  0.13        0.02
#  LinearSVC                                   0.13        0.02
#  GaussianNB                                  0.13        0.02
#  DecisionTreeClassifier                      0.13        0.03
#  CalibratedClassifierCV                      0.13        0.05
#  BernoulliNB                                 0.13        0.02
#  PassiveAggressiveClassifier                 0.11        0.00
#  Perceptron                                  0.06        0.01
#  ExtraTreeClassifier                         0.06        0.03
#  LogisticRegression                          0.04        0.01
#  DummyClassifier                             0.00        0.03
#  KNeighborsClassifier                       -0.03        0.03
#  BaggingClassifier                          -0.03        0.04
#  ExtraTreesClassifier                       -0.03        0.18
#  RandomForestClassifier                     -0.03        0.19
#  SGDClassifier                              -0.12        0.03
#  AdaBoostClassifier                         -0.12        0.07  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  PassiveAggressiveClassifier        0.76               0.76     0.76      0.76
#  XGBClassifier                      0.59               0.60     0.60      0.58
#  ExtraTreesClassifier               0.59               0.60     0.60      0.58
#  KNeighborsClassifier               0.59               0.60     0.60      0.58
#  NuSVC                              0.59               0.59     0.59      0.59
#  DecisionTreeClassifier             0.53               0.54     0.54      0.51
#  LabelPropagation                   0.53               0.54     0.54      0.51
#  LabelSpreading                     0.53               0.54     0.54      0.51
#  SVC                                0.53               0.53     0.53      0.53
#  SGDClassifier                      0.53               0.53     0.53      0.53
#  DummyClassifier                    0.47               0.50     0.50      0.30
#  AdaBoostClassifier                 0.47               0.48     0.48      0.46
#  RidgeClassifierCV                  0.47               0.48     0.48      0.46
#  RidgeClassifier                    0.47               0.48     0.48      0.46
#  LinearSVC                          0.47               0.48     0.48      0.46
#  LogisticRegression                 0.47               0.48     0.48      0.46
#  LinearDiscriminantAnalysis         0.47               0.48     0.48      0.46
#  ExtraTreeClassifier                0.47               0.48     0.48      0.46
#  CalibratedClassifierCV             0.47               0.48     0.48      0.46
#  LGBMClassifier                     0.47               0.48     0.48      0.46
#  NearestCentroid                    0.47               0.47     0.47      0.47
#  BernoulliNB                        0.47               0.47     0.47      0.47
#  Perceptron                         0.47               0.47     0.47      0.47
#  QuadraticDiscriminantAnalysis      0.41               0.42     0.42      0.39
#  RandomForestClassifier             0.41               0.42     0.42      0.39
#  GaussianNB                         0.41               0.42     0.42      0.41
#  BaggingClassifier                  0.35               0.37     0.37      0.31
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  PassiveAggressiveClassifier                 0.54        0.03
#  XGBClassifier                               0.20        0.04
#  ExtraTreesClassifier                        0.20        0.14
#  KNeighborsClassifier                        0.20        0.02
#  NuSVC                                       0.18        0.03
#  DecisionTreeClassifier                      0.09        0.02
#  LabelPropagation                            0.09        0.02
#  LabelSpreading                              0.09        0.01
#  SVC                                         0.07        0.01
#  SGDClassifier                               0.07        0.02
#  DummyClassifier                             0.00        0.03
#  AdaBoostClassifier                         -0.04        0.13
#  RidgeClassifierCV                          -0.04        0.02
#  RidgeClassifier                            -0.04        0.02
#  LinearSVC                                  -0.04        0.02
#  LogisticRegression                         -0.04        0.01
#  LinearDiscriminantAnalysis                 -0.04        0.03
#  ExtraTreeClassifier                        -0.04        0.01
#  CalibratedClassifierCV                     -0.04        0.04
#  LGBMClassifier                             -0.04        0.02
#  NearestCentroid                            -0.06        0.01
#  BernoulliNB                                -0.06        0.02
#  Perceptron                                 -0.07        0.03
#  QuadraticDiscriminantAnalysis              -0.17        0.02
#  RandomForestClassifier                     -0.17        0.11
#  GaussianNB                                 -0.17        0.02
#  BaggingClassifier                          -0.31        0.04  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  SVC                                0.82               0.82     0.82      0.82
#  LinearSVC                          0.76               0.77     0.77      0.76
#  RidgeClassifierCV                  0.76               0.77     0.77      0.76
#  RidgeClassifier                    0.76               0.77     0.77      0.76
#  GaussianNB                         0.76               0.77     0.77      0.76
#  RandomForestClassifier             0.76               0.77     0.77      0.76
#  LinearDiscriminantAnalysis         0.76               0.77     0.77      0.76
#  BaggingClassifier                  0.76               0.77     0.77      0.76
#  LogisticRegression                 0.76               0.77     0.77      0.76
#  NearestCentroid                    0.76               0.77     0.77      0.76
#  QuadraticDiscriminantAnalysis      0.71               0.71     0.71      0.71
#  XGBClassifier                      0.71               0.71     0.71      0.71
#  CalibratedClassifierCV             0.71               0.71     0.71      0.71
#  ExtraTreesClassifier               0.71               0.71     0.71      0.71
#  KNeighborsClassifier               0.65               0.66     0.66      0.63
#  LabelSpreading                     0.65               0.66     0.66      0.63
#  LGBMClassifier                     0.65               0.65     0.65      0.64
#  Perceptron                         0.65               0.65     0.65      0.65
#  AdaBoostClassifier                 0.65               0.64     0.64      0.64
#  LabelPropagation                   0.59               0.60     0.60      0.58
#  BernoulliNB                        0.59               0.59     0.59      0.59
#  PassiveAggressiveClassifier        0.53               0.55     0.55      0.48
#  NuSVC                              0.53               0.54     0.54      0.51
#  DecisionTreeClassifier             0.53               0.53     0.53      0.53
#  DummyClassifier                    0.47               0.50     0.50      0.30
#  SGDClassifier                      0.47               0.49     0.49      0.38
#  ExtraTreeClassifier                0.35               0.35     0.35      0.35
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  SVC                                         0.65        0.03
#  LinearSVC                                   0.55        0.02
#  RidgeClassifierCV                           0.55        0.01
#  RidgeClassifier                             0.55        0.02
#  GaussianNB                                  0.55        0.02
#  RandomForestClassifier                      0.55        0.14
#  LinearDiscriminantAnalysis                  0.55        0.02
#  BaggingClassifier                           0.55        0.03
#  LogisticRegression                          0.55        0.02
#  NearestCentroid                             0.55        0.02
#  QuadraticDiscriminantAnalysis               0.42        0.01
#  XGBClassifier                               0.42        0.04
#  CalibratedClassifierCV                      0.42        0.02
#  ExtraTreesClassifier                        0.42        0.11
#  KNeighborsClassifier                        0.35        0.02
#  LabelSpreading                              0.35        0.00
#  LGBMClassifier                              0.31        0.02
#  Perceptron                                  0.29        0.02
#  AdaBoostClassifier                          0.29        0.08
#  LabelPropagation                            0.20        0.00
#  BernoulliNB                                 0.18        0.01
#  PassiveAggressiveClassifier                 0.13        0.01
#  NuSVC                                       0.09        0.02
#  DecisionTreeClassifier                      0.07        0.02
#  DummyClassifier                             0.00        0.01
#  SGDClassifier                              -0.02        0.01
#  ExtraTreeClassifier                        -0.31        0.00  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  SGDClassifier                      0.76               0.78     0.78      0.77
#  BernoulliNB                        0.59               0.71     0.71      0.59
#  ExtraTreeClassifier                0.59               0.71     0.71      0.59
#  GaussianNB                         0.59               0.71     0.71      0.59
#  NearestCentroid                    0.65               0.69     0.69      0.66
#  LGBMClassifier                     0.53               0.67     0.67      0.52
#  CalibratedClassifierCV             0.53               0.67     0.67      0.52
#  SVC                                0.53               0.67     0.67      0.52
#  KNeighborsClassifier               0.53               0.67     0.67      0.52
#  NuSVC                              0.53               0.67     0.67      0.52
#  LogisticRegression                 0.59               0.65     0.65      0.60
#  RidgeClassifierCV                  0.59               0.65     0.65      0.60
#  RidgeClassifier                    0.59               0.65     0.65      0.60
#  LinearSVC                          0.59               0.65     0.65      0.60
#  LinearDiscriminantAnalysis         0.59               0.65     0.65      0.60
#  LabelSpreading                     0.59               0.65     0.65      0.60
#  LabelPropagation                   0.59               0.65     0.65      0.60
#  QuadraticDiscriminantAnalysis      0.53               0.61     0.61      0.54
#  XGBClassifier                      0.53               0.61     0.61      0.54
#  BaggingClassifier                  0.59               0.59     0.59      0.61
#  RandomForestClassifier             0.47               0.57     0.57      0.47
#  ExtraTreesClassifier               0.47               0.57     0.57      0.47
#  DecisionTreeClassifier             0.47               0.57     0.57      0.47
#  AdaBoostClassifier                 0.47               0.51     0.51      0.49
#  Perceptron                         0.29               0.50     0.50      0.13
#  DummyClassifier                    0.29               0.50     0.50      0.13
#  PassiveAggressiveClassifier        0.41               0.35     0.35      0.43
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  SGDClassifier                               0.51        0.02
#  BernoulliNB                                 0.42        0.04
#  ExtraTreeClassifier                         0.42        0.02
#  GaussianNB                                  0.42        0.02
#  NearestCentroid                             0.35        0.02
#  LGBMClassifier                              0.36        0.02
#  CalibratedClassifierCV                      0.36        0.07
#  SVC                                         0.36        0.00
#  KNeighborsClassifier                        0.36        0.00
#  NuSVC                                       0.36        0.02
#  LogisticRegression                          0.28        0.02
#  RidgeClassifierCV                           0.28        0.01
#  RidgeClassifier                             0.28        0.02
#  LinearSVC                                   0.28        0.02
#  LinearDiscriminantAnalysis                  0.28        0.01
#  LabelSpreading                              0.28        0.03
#  LabelPropagation                            0.28        0.01
#  QuadraticDiscriminantAnalysis               0.21        0.00
#  XGBClassifier                               0.21        0.05
#  BaggingClassifier                           0.17        0.07
#  RandomForestClassifier                      0.13        0.16
#  ExtraTreesClassifier                        0.13        0.08
#  DecisionTreeClassifier                      0.13        0.02
#  AdaBoostClassifier                          0.02        0.11
#  Perceptron                                  0.00        0.00
#  DummyClassifier                             0.00        0.02
#  PassiveAggressiveClassifier                -0.28        0.01  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  ExtraTreeClassifier                0.71               0.73     0.73      0.71
#  DecisionTreeClassifier             0.65               0.69     0.69      0.65
#  NuSVC                              0.71               0.66     0.66      0.70
#  SVC                                0.71               0.66     0.66      0.70
#  XGBClassifier                      0.65               0.65     0.65      0.65
#  BernoulliNB                        0.65               0.61     0.61      0.65
#  ExtraTreesClassifier               0.65               0.61     0.61      0.65
#  BaggingClassifier                  0.65               0.61     0.61      0.65
#  NearestCentroid                    0.65               0.61     0.61      0.65
#  CalibratedClassifierCV             0.59               0.61     0.61      0.60
#  PassiveAggressiveClassifier        0.59               0.61     0.61      0.60
#  LinearSVC                          0.59               0.57     0.57      0.59
#  RidgeClassifierCV                  0.59               0.57     0.57      0.59
#  RidgeClassifier                    0.59               0.57     0.57      0.59
#  RandomForestClassifier             0.59               0.57     0.57      0.59
#  QuadraticDiscriminantAnalysis      0.59               0.57     0.57      0.59
#  LGBMClassifier                     0.59               0.57     0.57      0.59
#  LogisticRegression                 0.59               0.57     0.57      0.59
#  LinearDiscriminantAnalysis         0.59               0.57     0.57      0.59
#  GaussianNB                         0.59               0.57     0.57      0.59
#  LabelSpreading                     0.53               0.52     0.52      0.54
#  LabelPropagation                   0.53               0.52     0.52      0.54
#  Perceptron                         0.41               0.51     0.51      0.36
#  DummyClassifier                    0.35               0.50     0.50      0.18
#  AdaBoostClassifier                 0.47               0.48     0.48      0.48
#  KNeighborsClassifier               0.53               0.45     0.45      0.50
#  SGDClassifier                      0.53               0.45     0.45      0.50
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  ExtraTreeClassifier                         0.45        0.00
#  DecisionTreeClassifier                      0.37        0.01
#  NuSVC                                       0.33        0.03
#  SVC                                         0.33        0.01
#  XGBClassifier                               0.29        0.04
#  BernoulliNB                                 0.23        0.01
#  ExtraTreesClassifier                        0.23        0.09
#  BaggingClassifier                           0.23        0.04
#  NearestCentroid                             0.23        0.02
#  CalibratedClassifierCV                      0.20        0.03
#  PassiveAggressiveClassifier                 0.20        0.02
#  LinearSVC                                   0.13        0.02
#  RidgeClassifierCV                           0.13        0.02
#  RidgeClassifier                             0.13        0.04
#  RandomForestClassifier                      0.13        0.21
#  QuadraticDiscriminantAnalysis               0.13        0.01
#  LGBMClassifier                              0.13        0.03
#  LogisticRegression                          0.13        0.00
#  LinearDiscriminantAnalysis                  0.13        0.02
#  GaussianNB                                  0.13        0.02
#  LabelSpreading                              0.04        0.01
#  LabelPropagation                            0.04        0.02
#  Perceptron                                  0.02        0.02
#  DummyClassifier                             0.00        0.02
#  AdaBoostClassifier                         -0.04        0.08
#  KNeighborsClassifier                       -0.12        0.02
#  SGDClassifier                              -0.12        0.01  ,
#                                 Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
#  Model
#  LabelPropagation                   0.76               0.76     0.76      0.76
#  LabelSpreading                     0.76               0.76     0.76      0.76
#  LGBMClassifier                     0.71               0.72     0.72      0.70
#  PassiveAggressiveClassifier        0.71               0.71     0.71      0.71
#  KNeighborsClassifier               0.71               0.71     0.71      0.71
#  BernoulliNB                        0.71               0.70     0.70      0.70
#  NuSVC                              0.71               0.70     0.70      0.70
#  QuadraticDiscriminantAnalysis      0.65               0.65     0.65      0.64
#  SGDClassifier                      0.59               0.60     0.60      0.58
#  LogisticRegression                 0.59               0.59     0.59      0.59
#  SVC                                0.59               0.59     0.59      0.59
#  RidgeClassifierCV                  0.59               0.59     0.59      0.59
#  RidgeClassifier                    0.59               0.59     0.59      0.59
#  NearestCentroid                    0.59               0.59     0.59      0.59
#  LinearSVC                          0.59               0.59     0.59      0.59
#  BaggingClassifier                  0.59               0.59     0.59      0.59
#  LinearDiscriminantAnalysis         0.59               0.59     0.59      0.59
#  GaussianNB                         0.59               0.59     0.59      0.59
#  ExtraTreesClassifier               0.59               0.59     0.59      0.59
#  CalibratedClassifierCV             0.59               0.59     0.59      0.59
#  RandomForestClassifier             0.53               0.53     0.53      0.53
#  ExtraTreeClassifier                0.53               0.53     0.53      0.53
#  XGBClassifier                      0.53               0.53     0.53      0.53
#  DummyClassifier                    0.47               0.50     0.50      0.30
#  AdaBoostClassifier                 0.47               0.47     0.47      0.47
#  DecisionTreeClassifier             0.47               0.47     0.47      0.47
#  Perceptron                         0.41               0.43     0.43      0.34
#
#                                 matthews_corrcoef  Time Taken
#  Model
#  LabelPropagation                            0.53        0.01
#  LabelSpreading                              0.53        0.02
#  LGBMClassifier                              0.45        0.03
#  PassiveAggressiveClassifier                 0.42        0.01
#  KNeighborsClassifier                        0.42        0.03
#  BernoulliNB                                 0.41        0.02
#  NuSVC                                       0.41        0.02
#  QuadraticDiscriminantAnalysis               0.31        0.02
#  SGDClassifier                               0.20        0.02
#  LogisticRegression                          0.18        0.02
#  SVC                                         0.18        0.02
#  RidgeClassifierCV                           0.18        0.02
#  RidgeClassifier                             0.18        0.02
#  NearestCentroid                             0.18        0.02
#  LinearSVC                                   0.18        0.00
#  BaggingClassifier                           0.18        0.04
#  LinearDiscriminantAnalysis                  0.18        0.01
#  GaussianNB                                  0.18        0.02
#  ExtraTreesClassifier                        0.18        0.13
#  CalibratedClassifierCV                      0.18        0.04
#  RandomForestClassifier                      0.07        0.19
#  ExtraTreeClassifier                         0.07        0.03
#  XGBClassifier                               0.07        0.06
#  DummyClassifier                             0.00        0.03
#  AdaBoostClassifier                         -0.06        0.12
#  DecisionTreeClassifier                     -0.07        0.02
#  Perceptron                                 -0.18        0.00  ]

# %%
predictions
# Out:
#     AdaBoostClassifier  BaggingClassifier  BernoulliNB  \
# 0                    1                  1            1
# 1                    1                  0            0
# 2                    1                  0            0
# 3                    0                  0            0
# 4                    0                  0            0
# 5                    0                  1            0
# 6                    1                  1            1
# 7                    1                  1            0
# 8                    0                  0            0
# 9                    1                  0            1
# 10                   1                  1            0
# 11                   0                  1            1
# 12                   0                  0            0
# 13                   0                  1            1
# 14                   1                  1            1
# 15                   1                  1            1
# 16                   0                  0            0
#
#     CalibratedClassifierCV  DecisionTreeClassifier  DummyClassifier  \
# 0                        1                       1                1
# 1                        0                       0                1
# 2                        0                       0                1
# 3                        0                       0                1
# 4                        0                       0                1
# 5                        0                       1                1
# 6                        1                       0                1
# 7                        1                       1                1
# 8                        0                       0                1
# 9                        1                       0                1
# 10                       1                       1                1
# 11                       1                       1                1
# 12                       0                       0                1
# 13                       1                       1                1
# 14                       1                       1                1
# 15                       1                       0                1
# 16                       0                       0                1
#
#     ExtraTreeClassifier  ExtraTreesClassifier  GaussianNB  \
# 0                     1                     1           1
# 1                     1                     0           0
# 2                     0                     0           0
# 3                     0                     0           0
# 4                     1                     0           0
# 5                     0                     0           0
# 6                     1                     1           1
# 7                     0                     1           1
# 8                     0                     0           0
# 9                     0                     1           1
# 10                    1                     1           1
# 11                    1                     1           1
# 12                    1                     0           0
# 13                    1                     1           1
# 14                    0                     1           1
# 15                    1                     1           1
# 16                    1                     0           0
#
#     KNeighborsClassifier  ...  PassiveAggressiveClassifier  Perceptron  \
# 0                      1  ...                            1           1
# 1                      0  ...                            0           1
# 2                      0  ...                            0           1
# 3                      0  ...                            0           1
# 4                      0  ...                            0           1
# 5                      0  ...                            0           1
# 6                      1  ...                            1           1
# 7                      1  ...                            1           1
# 8                      0  ...                            1           1
# 9                      0  ...                            1           1
# 10                     1  ...                            1           1
# 11                     1  ...                            1           0
# 12                     1  ...                            0           1
# 13                     1  ...                            0           0
# 14                     1  ...                            1           0
# 15                     1  ...                            1           1
# 16                     0  ...                            0           1
#
#     QuadraticDiscriminantAnalysis  RandomForestClassifier  RidgeClassifier  \
# 0                               1                       1                1
# 1                               0                       0                0
# 2                               0                       0                0
# 3                               0                       0                0
# 4                               0                       0                0
# 5                               0                       1                0
# 6                               1                       1                1
# 7                               1                       1                1
# 8                               1                       0                0
# 9                               1                       1                1
# 10                              1                       1                1
# 11                              1                       1                1
# 12                              0                       0                0
# 13                              1                       1                1
# 14                              1                       1                1
# 15                              1                       1                1
# 16                              0                       0                0
#
#     RidgeClassifierCV  SGDClassifier  SVC  XGBClassifier  LGBMClassifier
# 0                   1              1    1              1               1
# 1                   0              1    0              0               0
# 2                   0              1    0              1               1
# 3                   0              1    0              0               0
# 4                   0              0    0              0               0
# 5                   0              1    0              1               1
# 6                   1              1    1              1               1
# 7                   1              1    1              1               0
# 8                   0              0    0              0               1
# 9                   1              1    1              0               1
# 10                  1              0    1              1               1
# 11                  1              1    1              1               1
# 12                  0              1    0              0               1
# 13                  1              0    1              1               0
# 14                  1              0    1              1               1
# 15                  1              1    1              1               1
# 16                  0              0    0              0               0
#
# [17 rows x 27 columns]

# %%
accuracy
# Out:
# [['Plasma(Exploratory)', '0.8846105283605284'],
#  ['pca2_plasma(Exploratory)', '0.8141608391608391'],
#  ['pca3_plasma(Exploratory)', '0.8393550893550893'],
#  ['pca4_plasma(Exploratory)', '0.8237461149961149'],
#  ['pca5_plasma(Exploratory)', '0.8438422688422689'],
#  ['tsne2_plasma(Exploratory)', '0.7819638694638694'],
#  ['tsne3_plasma(Exploratory)', '0.7571474358974359']]

# %%
name
# Out:
# ['tsne3_plasma(Exploratory)']

# %%
name[idx]
# Out:
# 'tsne3_plasma(Exploratory)'

# %%
acc
# Out:
# [0.7803030303030303,
#  0.7152777777777778,
#  0.6923076923076923,
#  0.8819444444444444,
#  0.6515151515151515,
#  0.7569444444444444,
#  0.8194444444444444,
#  0.775,
#  0.7348484848484849,
#  0.7638888888888888]

# %%
accuracy_df = pd.DataFrame(accuracy, columns=['Processed Dataset', 'Accuracy'])
accuracy_df.to_csv('D:\GitHub\\4BIT\metabolites\\accuracy\\accuracy_exploratory_plasma2.csv', index=False)
accuracy_df
# Out:
#            Processed Dataset            Accuracy
# 0        Plasma(Exploratory)  0.8846105283605284
# 1   pca2_plasma(Exploratory)  0.8141608391608391
# 2   pca3_plasma(Exploratory)  0.8393550893550893
# 3   pca4_plasma(Exploratory)  0.8237461149961149
# 4   pca5_plasma(Exploratory)  0.8438422688422689
# 5  tsne2_plasma(Exploratory)  0.7819638694638694
# 6  tsne3_plasma(Exploratory)  0.7571474358974359

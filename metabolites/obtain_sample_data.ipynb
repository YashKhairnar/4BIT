# %%
import pandas as pd
import numpy as np

# %%
serum = pd.read_csv('D:\GitHub\\4BIT\metabolites\dataset\serum_processed.csv')
serum = serum.drop(['Unnamed: 0'], axis=1)
serum
# Out:
#     1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                  9582            279                               82
# 1                 28847            161                               78
# 2                 13627            162                               53
# 3                 20758           6671                               93
# 4                 15692            108                               98
# ..                  ...            ...                              ...
# 77                25194            108                              106
# 78                23525             83                              140
# 79                25154            418                               90
# 80                12397            110                              104
# 81                18350             73                              179
#
#     2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# ...

# %%
serum = serum.drop(columns = ["Class"])

# %%
head = serum.head()
head
# Out:
#    1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                 9582            279                               82
# 1                28847            161                               78
# 2                13627            162                               53
# 3                20758           6671                               93
# 4                15692            108                               98
#
#    2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                       61                357                   122
# 1                       84                205                   258
# 2                      133                139                   159
# 3                       78                335                   225
# 4                       69                250                   120
#
#    2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# ...

# %%
plasma_list = ['asparagine',
                'benzoic acid',
                'tryptophan',
                'uric acid',
                '5-hydroxynorvaline NIST',
                'alpha-ketoglutarate',
                'citrulline',
                'glutamine',
                'hypoxanthine',
                'malic acid',
                'methionine sulfoxide',
                'nornicotine',
                'octadecanol',
                '3-phosphoglycerate',
                '5-methoxytryptamine',
                'adenosine-5-monophosphate',
                'aspartic acid',
                'lactic acid',
                'maltose',
                'maltotriose',
                'N-methylalanine',
                'phenol',
                'phosphoethanolamine',
                'pyrophosphate',
                'pyruvic acid',
                'taurine']
serum_list = ['cholesterol',
            'lactic acid',
            'N-methylalanine',
            'phenylalanine',
            'aspartic acid',
            'deoxypentitol',
            'glutamic acid',
            'malic acid',
            'phenol',
            'taurine']

# %%
head.to_json('sample_data_serum.json' , orient = "records" , lines = True)

import json 

new_list = []
for i in range(len(head)) : 
    temp_list = []
    for j in plasma_list : 
        temp_list.append(head.loc[i,j])
    new_list.append(temp_list)

    with open('sampple_plasma_data.json', 'w', encoding='utf-8') as f:
        json.dump(temp_list, f, ensure_ascii=False, indent=4)


new_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 13
#      10     new_list.append(temp_list)
#      12     with open('sampple_plasma_data.json', 'w', encoding='utf-8') as f:
# ---> 13         json.dump(temp_list, f, ensure_ascii=False, indent=4)
#      16 new_list
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# ...

# %%
plasma =pd.read_csv("D:\GitHub\\4BIT\metabolites\dataset\plasma_processed.csv")
plasma.head()
# Out:
#    Unnamed: 0  1_5-anhydroglucitol  1-monostearin  \
# 0           1                 9483            103
# 1           2                27468            207
# 2           3                13976             86
# 3           4                19449            178
# 4           5                17209            258
#
#    2_3-dihydroxybutanoic acid NIST  2_4-diaminobutyric acid  \
# 0                              101                      963
# 1                              155                      335
# 2                               78                      176
# 3                              104                      467
# 4                              103                      979
#
#    2-deoxyerythritol  2-deoxytetronic acid  2-hydroxybutanoic acid  \
# 0                389                   123                   20744
# 1                227                   178                    8611
# 2                152                    83                   22792
# ...

# %%
plasma.drop(['Unnamed: 0'], axis=1 , inplace = True)

# %%
plasma.drop(['Class'] , axis = 1 , inplace = True)
plasma.head()
# Out:
#    1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                 9483            103                              101
# 1                27468            207                              155
# 2                13976             86                               78
# 3                19449            178                              104
# 4                17209            258                              103
#
#    2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                      963                389                   123
# 1                      335                227                   178
# 2                      176                152                    83
# 3                      467                270                   157
# 4                      979                314                   211
#
#    2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# ...

# %%
head2 = plasma.head()
head2
# Out:
#    1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                 9483            103                              101
# 1                27468            207                              155
# 2                13976             86                               78
# 3                19449            178                              104
# 4                17209            258                              103
#
#    2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                      963                389                   123
# 1                      335                227                   178
# 2                      176                152                    83
# 3                      467                270                   157
# 4                      979                314                   211
#
#    2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# ...

# %%
head2.to_json('sample_data_serum.json' , orient = 'records' , lines= True)
